# %%
import pandas as pd
import numpy as np

filename = "../data/tweet.csv"
df = pd.read_csv(filename)

# %%
df
# Out:
#      sentiment                                               text  \
# 0      neutral  RT @HenriVanhanen: Finland 🇫🇮 and NATO, an upd...
# 1      neutral  This thread is so worrying. MUST READ. No wond...
# 2      neutral  RT @AfricanWatchman: Our position on #UkraineW...
# 3      neutral  RT @DonnachaDCU: #Putin's side-kick, Dmitry Me...
# 4      neutral  RT @ALFO100897: 2/2\n...ripercussione la \risp...
# ...        ...                                                ...
# 1207   neutral  Ukrainian flag raised over Chernobyl, nuclear ...
# 1208   neutral  RT @JominiW: 1/ Ukrainian Theater of War, Day ...
# 1209   neutral  #Ukraine #UkraineWar #Russia #UkraineInvasion ...
# 1210  positive  RT @ADEYMARE: The absence of compassion from t...
# 1211  positive  Brovarsky district. APU 🇺🇦 is cleaning up. Rea...
#
#                  user
# 0              dbruhn
# 1        CJ_flyvictor
# 2     Julian_Roechelt
# 3       TheSwedishBot
# 4         anto_galli4
# ...               ...
# ...
